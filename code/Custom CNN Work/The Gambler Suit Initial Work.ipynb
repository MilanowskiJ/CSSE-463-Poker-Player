# %%
import numpy as np
import pandas as pd
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D,Flatten, Dropout
from tensorflow.keras.optimizers import SGD, Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
import matplotlib.pyplot as plt
from time import time
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.applications import InceptionResNetV2
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.linear_model import LogisticRegressionCV
from sklearn.model_selection import train_test_split

# %%
px = 410

# %%
rootdir = './custom_train/suit'
generator = ImageDataGenerator(rescale=1./255)
image_generator = generator.flow_from_directory(rootdir, target_size=(px,px), batch_size=659, class_mode='sparse')
# Out:
# Found 539 images belonging to 4 classes.

# %%
images, labels = image_generator.next()

# %%
images.shape
# Out:
# (539, 410, 410, 3)

# %%
plt.imshow(images[1])

# %%
X_train = images
y_train = labels

# %%
y_train.shape
# Out:
# (539,)

# %%
LR = 0.01
BS = 380 #20
EPOCHS = 50


EarlyStop = EarlyStopping(monitor='val_loss',patience=10)
SaveBest = ModelCheckpoint('TheGamblerGauss.h5',save_best_only=True, verbose = 2)

# %%
model = Sequential()

model.add(Conv2D(8,(3,3),activation = 'relu', input_shape=(px,px,3)))
model.add(Conv2D(8,(3,3),activation = 'relu'))
model.add(Conv2D(16,(5,5),activation = 'relu'))
model.add(Conv2D(16,(5,5),activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(16,(5,5),activation = 'relu'))
model.add(Conv2D(16,(5,5),activation = 'relu'))
model.add(Conv2D(32,(7,7),activation = 'relu'))
model.add(Conv2D(32,(7,7),activation = 'relu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(64,(7,7),activation = 'relu'))
model.add(Conv2D(64,(7,7),activation = 'relu'))
model.add(Conv2D(64,(7,7),activation = 'relu'))
model.add(Conv2D(64,(7,7),activation = 'relu'))

model.add(Flatten())
model.add(Dense(400,activation='relu'))
model.add(Dense(200,activation='relu'))
model.add(Dense(200,activation='relu'))
model.add(Dense(100,activation='relu'))
model.add(Dense(4,activation='softmax'))

# %%
model.compile(optimizer=Adam(learning_rate=LR),
              loss=SparseCategoricalCrossentropy(),
              metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f6e5d2d14865> in <module>
# ----> 1 model.compile(optimizer=Adam(learning_rate=LR),
#       2               loss='SparseCategoricalCrossentropy',
#       3               metrics=['accuracy'])
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/optimizers.py in __init__(self, lr, beta_1, beta_2, epsilon, decay, amsgrad, **kwargs)
#     472                amsgrad=False,
#     473                **kwargs):
# --> 474     super(Adam, self).__init__(**kwargs)
#     475     with K.name_scope(self.__class__.__name__):
#     476       self.iterations = K.variable(0, dtype='int64', name='iterations')
#
# /opt/anaconda3/lib/python3.6/site-packages/tensorflow/python/keras/optimizers.py in __init__(self, **kwargs)
#      91       if k not in allowed_kwargs:
#      92         raise TypeError('Unexpected keyword argument '
# ---> 93                         'passed to optimizer: ' + str(k))
#      94     self.__dict__.update(kwargs)
#      95     self.updates = []
#
# TypeError: Unexpected keyword argument passed to optimizer: learning_rate

# %%
hist = model.fit(X_train, y_train, epochs=EPOCHS, validation_split=0.2,
                 callbacks=[SaveBest]
                )
# Out:
# Train on 431 samples, validate on 108 samples
# Epoch 1/50
# 416/431 [===========================>..] - ETA: 5s - loss: 6289.2010 - accuracy: 0.2620
# Epoch 00001: val_loss improved from inf to 1.38648, saving model to TheGambler.h5
# 431/431 [==============================] - 184s 427ms/sample - loss: 6070.3685 - accuracy: 0.2599 - val_loss: 1.3865 - val_accuracy: 0.2500
# Epoch 2/50
# 416/431 [===========================>..] - ETA: 5s - loss: 10.4805 - accuracy: 0.2524
# Epoch 00002: val_loss did not improve from 1.38648
# 431/431 [==============================] - 165s 382ms/sample - loss: 10.1644 - accuracy: 0.2506 - val_loss: 1.3915 - val_accuracy: 0.2130
# Epoch 3/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3866 - accuracy: 0.2668
# Epoch 00003: val_loss did not improve from 1.38648
# 431/431 [==============================] - 165s 382ms/sample - loss: 1.3860 - accuracy: 0.2715 - val_loss: 1.3918 - val_accuracy: 0.2130
# Epoch 4/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3875 - accuracy: 0.2692
# Epoch 00004: val_loss did not improve from 1.38648
# 431/431 [==============================] - 165s 383ms/sample - loss: 1.3870 - accuracy: 0.2715 - val_loss: 1.3950 - val_accuracy: 0.2130
# Epoch 5/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3866 - accuracy: 0.2764
# Epoch 00005: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 381ms/sample - loss: 1.3874 - accuracy: 0.2715 - val_loss: 1.3932 - val_accuracy: 0.2130
# Epoch 6/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3864 - accuracy: 0.2692
# Epoch 00006: val_loss did not improve from 1.38648
# 431/431 [==============================] - 165s 382ms/sample - loss: 1.3863 - accuracy: 0.2715 - val_loss: 1.3900 - val_accuracy: 0.2130
# Epoch 7/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3863 - accuracy: 0.2668
# Epoch 00007: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3858 - accuracy: 0.2715 - val_loss: 1.3906 - val_accuracy: 0.2130
# Epoch 8/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3864 - accuracy: 0.2668
# Epoch 00008: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 379ms/sample - loss: 1.3861 - accuracy: 0.2715 - val_loss: 1.3906 - val_accuracy: 0.2130
# Epoch 9/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3855 - accuracy: 0.2716
# Epoch 00009: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 379ms/sample - loss: 1.3854 - accuracy: 0.2715 - val_loss: 1.3929 - val_accuracy: 0.2130
# Epoch 10/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3868 - accuracy: 0.2668
# Epoch 00010: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 381ms/sample - loss: 1.3862 - accuracy: 0.2715 - val_loss: 1.3946 - val_accuracy: 0.2130
# Epoch 11/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3864 - accuracy: 0.2692
# Epoch 00011: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3858 - accuracy: 0.2715 - val_loss: 1.3941 - val_accuracy: 0.2130
# Epoch 12/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3852 - accuracy: 0.2740
# Epoch 00012: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3857 - accuracy: 0.2715 - val_loss: 1.3927 - val_accuracy: 0.2130
# Epoch 13/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3849 - accuracy: 0.2740
# Epoch 00013: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3855 - accuracy: 0.2715 - val_loss: 1.3912 - val_accuracy: 0.2130
# Epoch 14/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3866 - accuracy: 0.2620
# Epoch 00014: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3857 - accuracy: 0.2715 - val_loss: 1.3901 - val_accuracy: 0.2130
# Epoch 15/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3872 - accuracy: 0.2692
# Epoch 00015: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3866 - accuracy: 0.2715 - val_loss: 1.3939 - val_accuracy: 0.2130
# Epoch 16/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3857 - accuracy: 0.2716
# Epoch 00016: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 379ms/sample - loss: 1.3858 - accuracy: 0.2715 - val_loss: 1.3937 - val_accuracy: 0.2130
# Epoch 17/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3861 - accuracy: 0.2668
# Epoch 00017: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3855 - accuracy: 0.2715 - val_loss: 1.3913 - val_accuracy: 0.2130
# Epoch 18/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3856 - accuracy: 0.2716
# Epoch 00018: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 377ms/sample - loss: 1.3856 - accuracy: 0.2715 - val_loss: 1.3911 - val_accuracy: 0.2130
# Epoch 19/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3851 - accuracy: 0.2764
# Epoch 00019: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3857 - accuracy: 0.2715 - val_loss: 1.3926 - val_accuracy: 0.2130
# Epoch 20/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3864 - accuracy: 0.2692
# Epoch 00020: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3860 - accuracy: 0.2715 - val_loss: 1.3910 - val_accuracy: 0.2130
# Epoch 21/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3843 - accuracy: 0.2788
# Epoch 00021: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3853 - accuracy: 0.2715 - val_loss: 1.3913 - val_accuracy: 0.2130
# Epoch 22/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3863 - accuracy: 0.2692
# Epoch 00022: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3861 - accuracy: 0.2715 - val_loss: 1.3905 - val_accuracy: 0.2130
# Epoch 23/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3852 - accuracy: 0.2716
# Epoch 00023: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3853 - accuracy: 0.2715 - val_loss: 1.3916 - val_accuracy: 0.2130
# Epoch 24/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3857 - accuracy: 0.2692
# Epoch 00024: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3855 - accuracy: 0.2715 - val_loss: 1.3923 - val_accuracy: 0.2130
# Epoch 25/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3868 - accuracy: 0.2644
# Epoch 00025: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3857 - accuracy: 0.2715 - val_loss: 1.3929 - val_accuracy: 0.2130
# Epoch 26/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3857 - accuracy: 0.2716
# Epoch 00026: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3858 - accuracy: 0.2715 - val_loss: 1.3942 - val_accuracy: 0.2130
# Epoch 27/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3867 - accuracy: 0.2668
# Epoch 00027: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3864 - accuracy: 0.2715 - val_loss: 1.3900 - val_accuracy: 0.2130
# Epoch 28/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3856 - accuracy: 0.2716
# Epoch 00028: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3854 - accuracy: 0.2715 - val_loss: 1.3899 - val_accuracy: 0.2130
# Epoch 29/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3866 - accuracy: 0.2716
# Epoch 00029: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3865 - accuracy: 0.2715 - val_loss: 1.3935 - val_accuracy: 0.2130
# Epoch 30/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3867 - accuracy: 0.2716
# Epoch 00030: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 377ms/sample - loss: 1.3864 - accuracy: 0.2715 - val_loss: 1.3934 - val_accuracy: 0.2130
# Epoch 31/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3873 - accuracy: 0.2740
# Epoch 00031: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3874 - accuracy: 0.2715 - val_loss: 1.3911 - val_accuracy: 0.2130
# Epoch 32/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3847 - accuracy: 0.2764
# Epoch 00032: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3857 - accuracy: 0.2715 - val_loss: 1.3910 - val_accuracy: 0.2130
# Epoch 33/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3862 - accuracy: 0.2644
# Epoch 00033: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3859 - accuracy: 0.2715 - val_loss: 1.3899 - val_accuracy: 0.2130
# Epoch 34/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3868 - accuracy: 0.2620
# Epoch 00034: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3861 - accuracy: 0.2715 - val_loss: 1.3904 - val_accuracy: 0.2130
# Epoch 35/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3870 - accuracy: 0.2692
# Epoch 00035: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3864 - accuracy: 0.2715 - val_loss: 1.3958 - val_accuracy: 0.2130
# Epoch 36/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3849 - accuracy: 0.2764
# Epoch 00036: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3860 - accuracy: 0.2715 - val_loss: 1.3956 - val_accuracy: 0.2130
# Epoch 37/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3858 - accuracy: 0.2716
# Epoch 00037: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3857 - accuracy: 0.2715 - val_loss: 1.3911 - val_accuracy: 0.2130
# Epoch 38/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3858 - accuracy: 0.2740
# Epoch 00038: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3860 - accuracy: 0.2715 - val_loss: 1.3921 - val_accuracy: 0.2130
# Epoch 39/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3852 - accuracy: 0.2740
# Epoch 00039: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3860 - accuracy: 0.2715 - val_loss: 1.3916 - val_accuracy: 0.2130
# Epoch 40/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3857 - accuracy: 0.2644
# Epoch 00040: val_loss did not improve from 1.38648
# 431/431 [==============================] - 162s 376ms/sample - loss: 1.3855 - accuracy: 0.2715 - val_loss: 1.3902 - val_accuracy: 0.2130
# Epoch 41/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3859 - accuracy: 0.2716
# Epoch 00041: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3859 - accuracy: 0.2715 - val_loss: 1.3935 - val_accuracy: 0.2130
# Epoch 42/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3851 - accuracy: 0.2740
# Epoch 00042: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 379ms/sample - loss: 1.3854 - accuracy: 0.2715 - val_loss: 1.3926 - val_accuracy: 0.2130
# Epoch 43/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3863 - accuracy: 0.2740
# Epoch 00043: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3866 - accuracy: 0.2715 - val_loss: 1.3912 - val_accuracy: 0.2130
# Epoch 44/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3856 - accuracy: 0.2716
# Epoch 00044: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3856 - accuracy: 0.2715 - val_loss: 1.3916 - val_accuracy: 0.2130
# Epoch 45/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3862 - accuracy: 0.2668
# Epoch 00045: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3858 - accuracy: 0.2715 - val_loss: 1.3895 - val_accuracy: 0.2130
# Epoch 46/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3858 - accuracy: 0.2692
# Epoch 00046: val_loss did not improve from 1.38648
# 431/431 [==============================] - 164s 380ms/sample - loss: 1.3856 - accuracy: 0.2715 - val_loss: 1.3922 - val_accuracy: 0.2130
# Epoch 47/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3855 - accuracy: 0.2716
# Epoch 00047: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3854 - accuracy: 0.2715 - val_loss: 1.3917 - val_accuracy: 0.2130
# Epoch 48/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3854 - accuracy: 0.2692
# Epoch 00048: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3855 - accuracy: 0.2715 - val_loss: 1.3933 - val_accuracy: 0.2130
# Epoch 49/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3859 - accuracy: 0.2692
# Epoch 00049: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 379ms/sample - loss: 1.3854 - accuracy: 0.2715 - val_loss: 1.3934 - val_accuracy: 0.2130
# Epoch 50/50
# 416/431 [===========================>..] - ETA: 5s - loss: 1.3853 - accuracy: 0.2740
# Epoch 00050: val_loss did not improve from 1.38648
# 431/431 [==============================] - 163s 378ms/sample - loss: 1.3856 - accuracy: 0.2715 - val_loss: 1.3920 - val_accuracy: 0.2130
